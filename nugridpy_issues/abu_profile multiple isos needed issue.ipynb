# %% [markdown]
# # NuGridpy Issue
# Issue: **abu_profile multiple isos needed**

# %% [markdown]
# ## Initialize session

# %%
# %pylab 
from nugridpy import nugridse as mp
from nugridpy import mesa as ms

data_dir="/data/nugrid_apod2/"    
#data_dir="/data/nugrid_vos/"    

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
pt=mp.se(mass=20,Z=0.02)
# Out:
# nugrid_path = /data/nugrid_apod2/
# closest set is set1.2 (Z = 0.02)
# closest mass is 20.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %% [markdown]
# ## The abu_profile method
# Works if you specify more than one species:

# %%
species=['C-12','O-16']
ifig=108;close(ifig);figure(ifig)
pt.abu_profile(isos=species, ifig=ifig, fname=18000, logy=True,colourblind=True)
ylim(-7,0)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-7, 0)

# %% [markdown]
# But it should also work if only one species is given:

# %%
species=['O-16']
ifig=108;close(ifig);figure(ifig)
pt.abu_profile(isos=species, ifig=ifig, fname=18000, logy=True)
ylim(-7,0)
xlim(0.552,0.556)
# Out:
# <div id='159fd094-0d34-4108-bf37-e0841b5cf3d4'></div>
#  reading ['iso_massf']...100%
# ValueErrorTraceback (most recent call last)
# <ipython-input-7-eb453dd46400> in <module>()
#       1 species=['O-16']
#       2 ifig=108;close(ifig);figure(ifig)
# ----> 3 pt.abu_profile(isos=species, ifig=ifig, fname=18000, logy=True)
#       4 ylim(-7,0)
#       5 xlim(0.552,0.556)
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in abu_profile(self, ixaxis, isos, ifig, fname, logy, colourblind)
#    4059             else:
#    4060                 pl.plot(x,y,u.linestyle(i)[0],markevery=u.linestyle(i)[1]*20,
# -> 4061                         label=names[i],mec='None')
#    4062
#    4063         pl.legend(loc='best').draw_frame(False)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
# ...

# %% [markdown]
# #### Task:
# * fix method so that it also works with only one species specified in list given to isos variable
