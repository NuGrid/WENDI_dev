# %% [markdown]
# # Analyses of NuGrid yield tables

# %% [markdown]
# ## I) Extract data with read_yields.py

# %%
import read_yields as ry
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6eedac10acc5> in <module>()
# ----> 1 import read_yields as ry
#
# ImportError: No module named read_yields

# %% [markdown]
# ### Read yield table of choice.

# %%
ry=ry.read_nugrid_yields('/home/nugrid/omega_sygma/yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt')

# %% [markdown]
# ### Each tabulated stellar model has the column attributes (single values):

# %%
ry.col_attrs
# Out:
# ['Table (M,Z)', 'Lifetime', 'Mfinal', 'CCSN energy']

# %% [markdown]
# ### To extract the Lifetime of a 1Msun stellar model at Z=0.02:

# %%
print ry.get(M=1,Z=0.02,quantity='Lifetime'),
# Out:
# 12150000000.0

# %% [markdown]
# ### Properties such as yields are stored in data columns

# %%
ry.data_cols
# Out:
# ['Isotopes', 'Yields', 'X0', 'Z', 'A']

# %% [markdown]
# ### The available isotopes can be extracted via

# %%
print ry.get(M=1,Z=0.02,quantity='Isotopes'),
# Out:
# ['H-1', 'H-2', 'He-3', 'He-4', 'Li-7', 'B-11', 'C-12', 'C-13', 'N-14', 'N-15', 'O-16', 'O-17', 'O-18', 'F-19', 'Ne-20', 'Ne-21', 'Ne-22', 'Na-23', 'Mg-24', 'Mg-25', 'Mg-26', 'Al-27', 'Si-28', 'Si-29', 'Si-30', 'P-31', 'Pb-206', 'Pb-207', 'S-32', 'S-33', 'S-34', 'S-36', 'Cl-35', 'Cl-37', 'Ar-36', 'Ar-38', 'Ar-40', 'K-39', 'K-40', 'K-41', 'Ca-40', 'Ca-42', 'Ca-43', 'Ca-44', 'Ca-46', 'Ca-48', 'Sc-45', 'Ti-46', 'Ti-47', 'Ti-48', 'Ti-49', 'Ti-50', 'V-50', 'V-51', 'Cr-50', 'Cr-52', 'Cr-53', 'Cr-54', 'Mn-55', 'Fe-54', 'Fe-56', 'Fe-57', 'Fe-58', 'Co-59', 'Ni-58', 'Ni-60', 'Ni-61', 'Ni-62', 'Ni-64', 'Cu-63', 'Cu-65', 'Zn-64', 'Zn-66', 'Zn-67', 'Zn-68', 'Zn-70', 'Ga-69', 'Ga-71', 'Ge-70', 'Ge-72', 'Ge-73', 'Ge-74', 'Ge-76', 'As-75', 'Se-74', 'Se-76', 'Se-77', 'Se-78', 'Se-80', 'Se-82', 'Br-79', 'Br-81', 'Kr-78', 'Kr-80', 'Kr-82', 'Kr-83', 'Kr-84', 'Kr-86', 'Rb-85', 'Rb-87', 'Sr-84', 'Sr-86', 'Sr-87', 'Sr-88', 'Y-89', 'Zr-90', 'Zr-91', 'Zr-92', 'Zr-94', 'Zr-96', 'Nb-93', 'Mo-92', 'Mo-94', 'Mo-95', 'Mo-96', 'Mo-97', 'Mo-98', 'Mo-100', 'Ru-96', 'Ru-98', 'Ru-99', 'Ru-100', 'Ru-101', 'Ru-102', 'Ru-104', 'Rh-103', 'Pd-102', 'Pd-104', 'Pd-105', 'Pd-106', 'Pd-108', 'Pd-110', 'Ag-107', 'Ag-109', 'Cd-106', 'Cd-108', 'Cd-110', 'Cd-111', 'Cd-112', 'Cd-113', 'Cd-114', 'Cd-116', 'In-113', 'In-115', 'Sn-112', 'Sn-114', 'Sn-115', 'Sn-116', 'Sn-117', 'Sn-118', 'Sn-119', 'Sn-120', 'Sn-122', 'Sn-124', 'Sb-121', 'Sb-123', 'Te-120', 'Te-122', 'Te-123', 'Te-124', 'Te-125', 'Te-126', 'Te-128', 'Te-130', 'I-127', 'Xe-124', 'Xe-126', 'Xe-128', 'Xe-129', 'Xe-130', 'Xe-131', 'Xe-132', 'Xe-134', 'Xe-136', 'Cs-133', 'Ba-130', 'Ba-132', 'Ba-134', 'Ba-135', 'Ba-136', 'Ba-137', 'Ba-138', 'La-138', 'La-139', 'Ce-136', 'Ce-138', 'Ce-140', 'Ce-142', 'Pr-141', 'Nd-142', 'Nd-143', 'Nd-144', 'Nd-145', 'Nd-146', 'Nd-148', 'Nd-150', 'Sm-144', 'Sm-147', 'Sm-148', 'Sm-149', 'Sm-150', 'Sm-152', 'Sm-154', 'Eu-151', 'Eu-153', 'Gd-152', 'Gd-154', 'Gd-155', 'Gd-156', 'Gd-157', 'Gd-158', 'Gd-160', 'Tb-159', 'Dy-156', 'Dy-158', 'Dy-160', 'Dy-161', 'Dy-162', 'Dy-163', 'Dy-164', 'Ho-165', 'Er-162', 'Er-164', 'Er-166', 'Er-167', 'Er-168', 'Er-170', 'Tm-169', 'Yb-168', 'Yb-170', 'Yb-171', 'Yb-172', 'Yb-173', 'Yb-174', 'Yb-176', 'Lu-175', 'Lu-176', 'Hf-174', 'Hf-176', 'Hf-177', 'Hf-178', 'Hf-179', 'Hf-180', 'Ta-180', 'Ta-181', 'W-180', 'W-182', 'W-183', 'W-184', 'W-186', 'Re-185', 'Re-187', 'Os-184', 'Os-186', 'Os-187', 'Os-188', 'Os-189', 'Os-190', 'Os-192', 'Ir-191', 'Ir-193', 'Pt-190', 'Pt-192', 'Pt-194', 'Pt-195', 'Pt-196', 'Pt-198', 'Au-197', 'Hg-196', 'Hg-198', 'Hg-199', 'Hg-200', 'Hg-201', 'Hg-202', 'Hg-204', 'Tl-203', 'Tl-205', 'Pb-204', 'Pb-208', 'Bi-209']

# %% [markdown]
# ### and the corresponding yields via

# %%
print ry.get(M=1,Z=0.02,quantity='Yields'),
# Out:
.488e-10, 1.283e-10, 8.955e-11, 9.905e-11, 1.296e-12, 1.412e-11, 9.642e-11, 1.342e-10, 1.033e-10, 1.649e-10, 1.47e-10, 1.216e-10, 4.415e-13, 7.665e-13, 1.892e-11, 1.539e-10, 2.088e-10, 2.051e-10, 2.336e-10, 1.867e-10, 7.077e-13, 8.414e-12, 1.779e-10, 1.221e-10, 1.435e-10, 8.093e-11, 8.156e-11, 6.964e-13, 1.648e-11, 7.786e-11, 1.197e-10, 8.898e-11, 1.766e-10, 7.172e-11, 8.04e-11, 1.919e-12, 5.416e-13, 1.787e-11, 6.324e-11, 9.331e-11, 4.685e-11, 1.213e-10, 1.068e-14, 8.734e-11, 3.692e-13, 8.258e-11, 4.485e-11, 9.654e-11, 9.054e-11, 4.609e-11, 7.455e-11, 3.127e-13, 2.542e-11, 2.982e-11, 2.144e-10, 2.628e-10, 4.296e-10, 6.742e-10, 5.97e-10, 1.015e-09, 4.436e-13, 2.573e-11, 1.095e-09, 1.13e-09, 8.472e-10, 2.429e-10, 4.765e-10, 1.324e-12, 8.687e-11, 1.478e-10, 2.033e-10, 1.166e-10, 2.655e-10, 6.164e-11, 1.417e-10, 3.415e-10, 1.289e-10, 3.893e-09, 3.835e-10]

# %% [markdown]
# ### To return the yield of specific species for example C-12 for stellar model of 1Msun at Z=0.01 try

# %%
print ry.get(M=1,Z=0.01,specie='C-12')
# Out:
# 0.0006964

# %% [markdown]
# ## II) Analyze data with SYGMA of the NUPYCEE framework

# %% [markdown]
# #### Read_yields.py is part of the NUPYCEE package at  http://nugrid.github.io/NuPyCEE/ and hence you can apply the same commands as for read_yields.py above.
# #### With NUPYCEE it possible to plot quantities analyze the chemical evolution based on isotope tables.

# %%
import sygma as s

# %%
yield_table='yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt'

# %% [markdown]
# ### Start a SYGMA instance.

# %%
s1=s.sygma(table=yield_table)
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.29s

# %% [markdown]
# #### The same features of read_yields.py are available via s1.ytables within SYGMA. For example:

# %%
s1.ytables.get(M=1,Z=0.01,specie='C-12')
# Out:
# 0.0006964

# %% [markdown]
# ### Now you can plot quantities:

# %%
s1.plot_table_yield(fig=1,yaxis='C-12',iniZ=0.02,table=yield_table)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Column attributes are again available header of the yield tables:

# %%
s1.ytables.col_attrs
# Out:
# ['Table (M,Z)', 'Lifetime', 'Mfinal', 'CCSN energy']

# %%
s1.plot_table_param(fig=2,quantity='Lifetime',iniZ=0.02,table=yield_table)
# Out:
# <img src="data:image/png;base64,...">

# %%
s1.plot_table_param(fig=3,quantity='Mfinal',iniZ=0.02,table=yield_table)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### You can analyze the chemical evolution of isotopes and elements, for example C-12 for certain simple stellar populations.

# %%
s1.plot_mass(specie='C-12')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### For more example see the NUPYCEE page.
